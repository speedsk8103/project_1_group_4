# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# %%
# Study data files
fifteen = "resources/2015.csv"
sixteen = "resources/2016.csv"
seventeen = "resources/2017.csv"
eighteen = "resources/2018_new.csv"
nineteen = "resources/2019.csv"

# Read the mouse data and the study results
fifteen_data = pd.read_csv(fifteen)
sixteen_data = pd.read_csv(sixteen)
seventeen_data = pd.read_csv(seventeen)
eighteen_data = pd.read_csv(eighteen)
nineteen_data = pd.read_csv(nineteen)

#change into dataframes
fif_df = pd.DataFrame(fifteen_data)
six_df = pd.DataFrame(sixteen_data)
sev_df = pd.DataFrame(seventeen_data)
eight_df = pd.DataFrame(eighteen_data)
nine_df = pd.DataFrame(nineteen_data)

# %%
# create dataframes showing top 5 and bottom 5 ranking on the happiness score and trust in government for each year.

# 2015 top 5
fif_top_5 = fif_df.iloc[0:5]
fif_top_5[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]
fif_top_5 = fif_top_5[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]
# 2015 bottom 5
fif_last_5 = fif_df.iloc[152:157]
fif_last_5[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]
fif_last_5 = fif_last_5[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]

#fif_top_5 = pd.DataFrame({'Country': [0], 'Happiness Rank': [1], "Happiness Score" : [2], "Trust(Government Corruption)" : [5]})
#fif_top_5 = fif_top_5.rename(columns={fif_top_5.columns[5]: 'Trust(Government Corruption)'})

# %%
fif_top_5
# Out:
#        Country  Happiness Rank  Happiness Score  Trust (Government Corruption)
# 0  Switzerland               1            7.587                        0.41978
# 1      Iceland               2            7.561                        0.14145
# 2      Denmark               3            7.527                        0.48357
# 3       Norway               4            7.522                        0.36503
# 4       Canada               5            7.427                        0.32957

# %%
fif_last_5
# Out:
#          Country  Happiness Rank  Happiness Score  \
# 152  Afghanistan             153            3.575
# 153       Rwanda             154            3.465
# 154        Benin             155            3.340
# 155        Syria             156            3.006
# 156      Burundi             157            2.905
#
#      Trust (Government Corruption)
# 152                        0.09719
# 153                        0.55191
# 154                        0.08010
# 155                        0.18906
# 156                        0.10062

# %%
# create dataframes showing top 5 and bottom 5 ranking on the happiness score and trust in government for each year

# 2016 top 5
six_top_5 = six_df.iloc[0:5]
six_df[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]
six_top_5 = six_top_5[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]
# 2016 bottom 5
six_last_5 = six_df.iloc[152:157]
six_last_5[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]
six_last_5 = six_last_5[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]

# %%
six_top_5
# Out:
#        Country  Happiness Rank  Happiness Score  Trust (Government Corruption)
# 0      Denmark               1            7.526                        0.44453
# 1  Switzerland               2            7.509                        0.41203
# 2      Iceland               3            7.501                        0.14975
# 3       Norway               4            7.498                        0.35776
# 4      Finland               5            7.413                        0.41004

# %%
six_last_5
# Out:
#          Country  Happiness Rank  Happiness Score  \
# 152        Benin             153            3.484
# 153  Afghanistan             154            3.360
# 154         Togo             155            3.303
# 155        Syria             156            3.069
# 156      Burundi             157            2.905
#
#      Trust (Government Corruption)
# 152                        0.06681
# 153                        0.07112
# 154                        0.11587
# 155                        0.17233
# 156                        0.09419

# %%
# create dataframes showing top 5 and bottom 5 ranking on the happiness score and trust in government for each year

# 2017 top 5
sev_top_5 = sev_df.iloc[0:5]
sev_df[["Country", "Happiness.Rank", "Happiness.Score", "Trust..Government.Corruption."]]
sev_top_5 = sev_top_5[["Country", "Happiness.Rank", "Happiness.Score", "Trust..Government.Corruption."]]

# 2017 bottom 5
sev_last_5 = sev_df.iloc[151:155]
sev_last_5[["Country", "Happiness.Rank", "Happiness.Score", "Trust..Government.Corruption."]]
sev_last_5 = sev_last_5[["Country", "Happiness.Rank", "Happiness.Score", "Trust..Government.Corruption."]]
#rename columns for continuity.
clean_sev_top = sev_top_5[["Country", "Happiness.Rank", "Happiness.Score",
                           "Trust..Government.Corruption."]]                                
clean_sev_top = clean_sev_top.rename(columns={"Happiness.Rank":"Happiness Rank",
                                              "Happiness.Score":"Happiness Score",
                                              "Trust..Government.Corruption.":"Trust (Government Corruption)"})

clean_sev_last = sev_last_5[["Country", "Happiness.Rank", "Happiness.Score",
                             "Trust..Government.Corruption."]]                                
clean_sev_last = clean_sev_last.rename(columns={"Happiness.Rank":"Happiness Rank",
                                                "Happiness.Score":"Happiness Score",
                                                "Trust..Government.Corruption.":"Trust (Government Corruption)"})

# %%
clean_sev_top.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Trust (Government Corruption)
# 0       Norway               1            7.537                       0.315964
# 1      Denmark               2            7.522                       0.400770
# 2      Iceland               3            7.504                       0.153527
# 3  Switzerland               4            7.494                       0.367007
# 4      Finland               5            7.469                       0.382612

# %%
clean_sev_last
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Trust (Government Corruption)
# 151                       0.151347
# 152                       0.066035
# 153                       0.084148
# 154                       0.056565

# %%
# create dataframes showing top 5 and bottom 5 ranking on the happiness score and trust in government for each year

# 2018 top 5
eight_top_5 = eight_df.iloc[0:5]
eight_df[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]
eight_top_5 = eight_top_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]
# 2018 bottom 5
eight_last_5 = eight_df.iloc[151:155]
eight_last_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]
eight_last_5 = eight_last_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]

#rename columns for continuity.
clean_eight_top = eight_top_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]                                
clean_eight_top = clean_eight_top.rename(columns={"Country or region":"Country",
                                                  "Score":"Happiness Score",
                                                  "Overall rank":"Happiness Rank",
                                                  "Perceptions of corruption":"Trust (Government Corruption)"})

clean_eight_last = eight_last_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]                                
clean_eight_last = clean_eight_last.rename(columns={"Country or region":"Country", 
                                                    "Overall rank":"Happiness Rank",
                                                    "Score":"Happiness Score",
                                                    "Perceptions of corruption":"Trust (Government Corruption)"})

# %%
clean_eight_top
# Out:
#        Country  Happiness Rank  Happiness Score  Trust (Government Corruption)
# 0      Finland               1            7.632                          0.393
# 1       Norway               2            7.594                          0.340
# 2      Denmark               3            7.555                          0.408
# 3      Iceland               4            7.495                          0.138
# 4  Switzerland               5            7.487                          0.357

# %%
clean_eight_last
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 151                     Yemen             152            3.355
# 152                  Tanzania             153            3.303
# 153               South Sudan             154            3.254
# 154  Central African Republic             155            3.083
#
#      Trust (Government Corruption)
# 151                          0.064
# 152                          0.097
# 153                          0.106
# 154                          0.038

# %%
# create dataframes showing top 5 and bottom 5 ranking on the happiness score and trust in government for each year

# 2019 top 5
nine_top_5 = nine_df.iloc[0:5]
nine_df[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]
nine_top_5 = nine_top_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]
# 2019 bottom 5
nine_last_5 = nine_df.iloc[151:155]
nine_last_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]
nine_last_5 = nine_last_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]

#rename columns for continuity.
clean_nine_top = nine_top_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]                                
clean_nine_top = clean_nine_top.rename(columns={"Country or region":"Country",
                                                "Overall rank":"Happiness Rank",
                                                  "Score":"Happiness Score",
                                                  "Perceptions of corruption":"Trust (Government Corruption)"})

clean_nine_last = nine_last_5[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]                                
clean_nine_last = clean_nine_last.rename(columns={"Country or region":"Country", 
                                                    "Overall rank":"Happiness Rank",
                                                    "Score":"Happiness Score",
                                                    "Perceptions of corruption":"Trust (Government Corruption)"})

# %%
clean_nine_top
# Out:
#        Country  Happiness Rank  Happiness Score  Trust (Government Corruption)
# 0      Finland               1            7.769                          0.393
# 1      Denmark               2            7.600                          0.410
# 2       Norway               3            7.554                          0.341
# 3      Iceland               4            7.494                          0.118
# 4  Netherlands               5            7.488                          0.298

# %%
clean_nine_last
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 151                    Rwanda             152            3.334
# 152                  Tanzania             153            3.231
# 153               Afghanistan             154            3.203
# 154  Central African Republic             155            3.083
#
#      Trust (Government Corruption)
# 151                          0.411
# 152                          0.147
# 153                          0.025
# 154                          0.035

# %%
fif = fif_df.copy()
six = six_df.copy()
sev = sev_df.copy()
eight = eight_df.copy()
nine = nine_df.copy()

#rename columns for continuity.
sev = sev[["Country", "Happiness.Rank", "Happiness.Score",
                           "Trust..Government.Corruption."]]                                
sev = sev.rename(columns={"Happiness.Rank":"Happiness Rank",
                                              "Happiness.Score":"Happiness Score",
                                              "Trust..Government.Corruption.":"Trust (Government Corruption)"})

eight = eight[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]                                
eight = eight.rename(columns={"Country or region":"Country",
                                                "Overall rank":"Happiness Rank",
                                                  "Score":"Happiness Score",
                                                  "Perceptions of corruption":"Trust (Government Corruption)"})

nine = nine[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]                                
nine = nine.rename(columns={"Country or region":"Country",
                                                "Overall rank":"Happiness Rank",
                                                  "Score":"Happiness Score",
                                                  "Perceptions of corruption":"Trust (Government Corruption)"})

# %%
#calculate mean of happiness score and trust in government columns for each year's dataset. include linear regression.
#2015

x_values = fif_df['Trust (Government Corruption)']
y_values = fif_df['Happiness Score']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors="black", facecolors="steelblue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Trust of Government and Happiness Scores 2015")
plt.xlabel("Trust of Government")
plt.ylabel("Happiness Score")

plt.savefig('images/trust_2015.png')
plt.show()
# Correlation between Trust of Government/Happiness Score in 2015.
correlation = st.pearsonr(x_values,y_values)
correlation
# Out:
# PearsonRResult(statistic=0.39519858383691125, pvalue=2.763802425204147e-07)

# %%
#calculate mean of happiness score and trust in government columns for each year's dataset. include linear regression.
#2016
x_values = six_df['Trust (Government Corruption)']
y_values = six_df['Happiness Score']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors="black", facecolors="steelblue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Trust of Government and Happiness Scores 2016")
plt.xlabel("Trust of Government")
plt.ylabel("Happiness Score")
plt.savefig('images/trust_2016.png')
# Correlation between Trust of Government/Happiness Score in 2016.
correlation = st.pearsonr(x_values,y_values)
plt.show()
correlation
# Out:
# PearsonRResult(statistic=0.40203224514729263, pvalue=1.797842658402267e-07)

# %%
#rename columns of copied datasets for continuity
clean_17 = sev_df[["Country", "Happiness.Rank", "Happiness.Score",
                           "Trust..Government.Corruption."]]                                
clean_17 = clean_17.rename(columns={"Happiness.Rank":"Happiness Rank",
                                              "Happiness.Score":"Happiness Score",
                                              "Trust..Government.Corruption.":"Trust (Government Corruption)"})
clean_17
#calculate mean of happiness score and trust in government columns for each year's dataset. include linear regression.
#2017
trust = clean_17["Trust (Government Corruption)"]
score = clean_17["Happiness Score"]
plt.scatter(trust, score, marker="o", edgecolors="black", facecolors="steelblue")
#linear regression
x_values = clean_17['Trust (Government Corruption)']
y_values = clean_17['Happiness Score']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors="black", facecolors="steelblue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Trust of Government and Happiness Scores 2017")
plt.xlabel("Trust of Government")
plt.ylabel("Happiness Score")
plt.savefig('images/trust_2017.png')
plt.show()
# Correlation between Trust of Government/Happiness Score in 2017.
correlation = st.pearsonr(x_values,y_values)
plt.show()
correlation
# Out:
# PearsonRResult(statistic=0.4290797372221721, pvalue=2.538310699741526e-08)

# %%
#rename columns for continuity.
import matplotlib.pyplot as plt
from scipy.stats import linregress

clean_18 = eight_df[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]
clean_18 = clean_18.rename(columns={"Country or region":"Country",
                                                  "Score":"Happiness Score",
                                                  "Overall rank":"Happiness Rank",
                                                  "Perceptions of corruption":"Trust (Government Corruption)"})
clean_18[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]

# calculate mean of happiness score and trust in government columns for each year's dataset. include linear regression.
# 2018
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot the scatter plot and the regression line
plt.figure(figsize=(8, 6))
plt.scatter(x_values, y_values,edgecolors="black", facecolors="steelblue")
plt.plot(x_values, regress_values, "r-")
plt.title("Trust of Government and Happiness Scores 2018")
plt.xlabel("Trust of Government")
plt.ylabel("Happiness Score")
plt.savefig('images/trust_2018.png')
plt.show()
# Correlation between Trust of Government/Happiness Score in 2018.
correlation = st.pearsonr(x_values,y_values)
plt.show()
correlation
# Out:
# PearsonRResult(statistic=0.4290797372221721, pvalue=2.538310699741526e-08)

# %%
#rename columns for continuity.
clean_19 = nine_df[["Country or region", "Overall rank", "Score", "Perceptions of corruption"]]                                
clean_19 = clean_19.rename(columns={"Country or region":"Country",
                                                "Overall rank":"Happiness Rank",
                                                  "Score":"Happiness Score",
                                                  "Perceptions of corruption":"Trust (Government Corruption)"})
clean_19[["Country", "Happiness Rank", "Happiness Score", "Trust (Government Corruption)"]]

#calculate mean of happiness score and trust in government columns for each year's dataset. include linear regression.
#2019
x_values = clean_19['Trust (Government Corruption)']
y_values = clean_19['Happiness Score']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,edgecolors="black", facecolors="steelblue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Trust of Government and Happiness Scores 2019")
plt.xlabel("Trust of Government")
plt.ylabel("Happiness Score")
plt.savefig('images/trust_2019.png')
plt.show()
# Correlation between Trust of Government/Happiness Score in 2019.
correlation = st.pearsonr(x_values,y_values)
plt.show()
correlation
# Out:
# PearsonRResult(statistic=0.3856130708664788, pvalue=6.654010938470258e-07)

# %%
#examine each factor's correlation with the overall happiness score
